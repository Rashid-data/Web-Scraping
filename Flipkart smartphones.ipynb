# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Step 1: Fetch the HTML content of the Flipkart smartphones page
url = "https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&param=1112&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIlJlYWxtZSBzbWFydHBob25lcyJdLCJ2YWx1ZVR5cGUiOiJNVUxUSV9WQUxVRUQifX19fX0%3D&wid=33.productCard.PMU_V2_29"
response = requests.get(url)
html_content = response.content

# %%
# Step 2: Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
# Step 3: Extract relevant information
products = soup.find_all('div', {'class': '_1AtVbE'})
# Initialize lists to store data
names = []
prices = []
ratings = []

# Extract data and store in lists
for product in products:
    name = product.find('div', {'class': '_4rR01T'})
    price = product.find('div', {'class': '_30jeq3 _1_WHN1'})
    rating = product.find('div', {'class': '_3LWZlK'})

    if name:
        names.append(name.text.strip())
    else:
        names.append(None)

    if price:
        prices.append(price.text.strip())
    else:
        prices.append(None)

    if rating:
        ratings.append(rating.text.strip())
    else:
        ratings.append(None)

# %%
# Step 4: Create a Pandas DataFrame
data = {'Name': names, 'Price': prices, 'Rating': ratings}
df = pd.DataFrame(data)

# %%
#Step 5: Data Cleaning
# Convert numerical data types to int or float
df['Price'] = df['Price'].str.replace('₹', '').str.replace(',', '').astype(float)

# %%
# Display the DataFrame
df.head(20)
# Out:
#                                           Name    Price Rating
# 0                                         None      NaN   None
# 1                                         None      NaN   None
# 2                                         None      NaN   None
# 3               APPLE iPhone 14 (Blue, 128 GB)  58999.0    4.6
# 4           APPLE iPhone 14 (Midnight, 128 GB)  59999.0    4.6
# 5          APPLE iPhone 14 (Starlight, 128 GB)  59999.0    4.6
# 6    SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)  12490.0    4.2
# 7         MOTOROLA g54 5G (Mint Green, 128 GB)  13999.0    4.2
# 8      MOTOROLA g54 5G (Midnight Blue, 128 GB)  13999.0    4.2
# 9   SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)  12490.0    4.2
# 10    APPLE iPhone 14 Plus (Starlight, 128 GB)  67999.0    4.6
# 11            APPLE iPhone 14 (Purple, 128 GB)  59999.0    4.6
# 12   MOTOROLA Edge 40 Neo (Caneel Bay, 128 GB)  22999.0    4.4
# 13       APPLE iPhone 14 Plus (Purple, 128 GB)  67999.0    4.6
# ...

# %%
df.to_csv("Flipkart_smartphones.csv", index=False)
